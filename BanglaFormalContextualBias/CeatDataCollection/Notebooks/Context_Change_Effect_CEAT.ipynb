# %%
# !pip install seaborn matplotlib

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # BanglaBERT Large (Discriminator)

# %%
data_bbldisc = {
    "W1": [(9, 0.584), (15, 0.475), (20, 0.439), (25, 0.452), (30, 0.477), (40, 0.503),
           (50, 0.462), (60, 0.452), (75, 0.503), (100, 0.424), (125, 0.472)],
    "W2": [(9, -0.306), (15, -0.197), (20, -0.174), (25, -0.171), (30, -0.141),
           (40, -0.164), (50, -0.187), (60, -0.184), (75, -0.202), (100, -0.143),
           (125, -0.159)],
    "W3": [(9, -0.016), (15, -0.009), (20, 0.028), (25, 0.033), (30, 0.030),
           (40, -0.001), (50, 0.025), (60, 0.025), (75, 0.025), (100, 0.025),
           (125, 0.035)],
    "W4": [(9, 0.020), (15, 0.020), (20, 0.002), (25, 0.002), (30, 0.005),
           (40, 0.020), (50, 0.008), (60, 0.005), (75, 0.008), (100, 0.005),
           (125, 0.005)],
    "W5": [(10, -0.057), (15, -0.044), (20, -0.052), (25, -0.062), (30, -0.052),
           (40, -0.016), (50, -0.027), (60, -0.039), (75, -0.019), (100, -0.037),
           (125, -0.019)],
    "W6": [(9, -0.001), (15, 0.051), (20, 0.068), (25, 0.084), (30, 0.076),
           (40, 0.066), (50, 0.071), (60, 0.068), (75, 0.066), (100, 0.063),
           (125, 0.076)],
    "W7": [(9, 0.228), (15, 0.264), (20, 0.254), (25, 0.249), (30, 0.244),
           (40, 0.249), (50, 0.254), (60, 0.267), (75, 0.277), (100, 0.282),
           (125, 0.267)],
    "W8": [(9, -0.052), (15, 0.008), (20, -0.019), (25, -0.032), (30, -0.034),
           (40, -0.042), (50, -0.047), (60, -0.057), (75, -0.060), (100, -0.052),
           (125, -0.052)],
    "W9": [(9, -0.093), (15, -0.100), (20, -0.121), (25, -0.146), (30, -0.166),
           (40, -0.174), (50, -0.169), (60, -0.161), (75, -0.181), (100, -0.171),
           (125, -0.179)]
}

# %%
plt.figure(figsize=(14, 8))
for i, (segment_name, points) in enumerate(data_bbldisc.items()):
    x, y = zip(*points)
    x_positions = [xi + i * 0.5 for xi in x]
    plt.bar(x_positions, y, width=0.5, label=segment_name)

plt.title('BBERT-L-D (F) $l$ vs $d$')
plt.xlabel('$l$')
plt.ylabel('$d$')
plt.legend(title="")

plt.savefig('BBERT-L-D (F).pdf')

# %% [markdown]
# # XLM RoBERTa Large

# %%
data_xlmrobertal = {
    "W1": [(9, -0.026), (15, 0.072), (20, 0.081), (25, 0.136), (30, 0.158),
           (40, 0.213), (50, 0.230), (60, 0.238), (75, 0.226), (100, 0.192),
           (125, 0.230)],
    "W2": [(9, 0.524), (15, 0.724), (20, 0.741), (25, 0.762), (30, 0.762),
           (40, 0.792), (50, 0.775), (60, 0.792), (75, 0.804), (100, 0.809),
           (125, 0.826)],
    "W3": [(9, 0.128), (15, 0.043), (20, 0.017), (25, 0.043), (30, 0.026),
           (40, 0.026), (50, 0.030), (60, 0.043), (75, 0.043), (100, 0.043),
           (125, 0.047)],
    "W4": [(9, -0.115), (15, -0.183), (20, -0.175), (25, -0.209), (30, -0.192),
           (40, -0.192), (50, -0.196), (60, -0.204), (75, -0.209), (100, -0.187),
           (125, -0.213)],
    "W5": [(9, 0.311), (15, 0.298), (20, 0.272), (25, 0.230), (30, 0.213),
           (40, 0.179), (50, 0.183), (60, 0.196), (75, 0.183), (100, 0.221),
           (125, 0.200)],
    "W6": [(9, -0.289), (15, -0.226), (20, -0.200), (25, -0.170), (30, -0.158),
           (40, -0.141), (50, -0.132), (60, -0.141), (75, -0.094), (100, -0.081),
           (125, -0.153)],
    "W7": [(9, -0.719), (15, -0.724), (20, -0.770), (25, -0.838), (30, -0.834),
           (40, -0.838), (50, -0.855), (60, -0.868), (75, -0.838), (100, -0.847),
           (125, -0.843)],
    "W8": [(9, -0.328), (15, -0.349), (20, -0.349), (25, -0.362), (30, -0.370),
           (40, -0.383), (50, -0.375), (60, -0.366), (75, -0.345), (100, -0.379),
           (125, -0.362)],
    "W9": [(9, -0.196), (15, -0.128), (20, -0.124), (25, -0.111), (30, -0.124),
           (40, -0.124), (50, -0.115), (60, -0.119), (75, -0.124), (100, -0.141),
           (125, -0.132)]
}

# %%
plt.figure(figsize=(14, 8))
for i, (segment_name, points) in enumerate(data_xlmrobertal.items()):
    x, y = zip(*points)
    x_positions = [xi + i * 0.5 for xi in x]
    plt.bar(x_positions, y, width=0.5, label=segment_name)

plt.title('XLM-RoBERTa-L (F) $l$ vs $d$')
plt.xlabel('$l$')
plt.ylabel('$d$')
plt.legend(title="", loc='upper right')

plt.savefig('XLM-RoBERTa-L (F).pdf')

# %%
# !pip install seaborn matplotlib

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # BanglaBERT Large (Discriminator)

# %%
data_bbldisc = {
    "W1": [
        (9, 0.586), (15, 0.477), (20, 0.441), (25, 0.454), (30, 0.479),
        (40, 0.505), (50, 0.464), (60, 0.454), (75, 0.505), (100, 0.426),
        (125, 0.474)
    ],
    "W2": [
        (9, -0.308), (15, -0.199), (20, -0.176), (25, -0.173), (30, -0.143),
        (40, -0.166), (50, -0.189), (60, -0.186), (75, -0.204), (100, -0.145),
        (125, -0.161)
    ],
    "W3": [
        (9, -0.018), (15, -0.011), (20, 0.030), (25, 0.035), (30, 0.032),
        (40, -0.003), (50, 0.027), (60, 0.027), (75, 0.027), (100, 0.027),
        (125, 0.037)
    ],
    "W4": [
        (9, 0.022), (15, 0.022), (20, 0.004), (25, 0.004), (30, 0.007),
        (40, 0.022), (50, 0.010), (60, 0.007), (75, 0.010), (100, 0.007),
        (125, 0.007)
    ],
    "W5": [
        (10, -0.059), (15, -0.046), (20, -0.054), (25, -0.064), (30, -0.054),
        (40, -0.018), (50, -0.029), (60, -0.041), (75, -0.021), (100, -0.039),
        (125, -0.021)
    ],
    "W6": [
        (9, -0.003), (15, 0.053), (20, 0.070), (25, 0.086), (30, 0.078),
        (40, 0.068), (50, 0.073), (60, 0.070), (75, 0.068), (100, 0.065),
        (125, 0.078)
    ],
    "W7": [
        (9, 0.230), (15, 0.266), (20, 0.256), (25, 0.251), (30, 0.246),
        (40, 0.251), (50, 0.256), (60, 0.269), (75, 0.279), (100, 0.284),
        (125, 0.269)
    ],
    "W8": [
        (9, -0.054), (15, 0.010), (20, -0.021), (25, -0.034), (30, -0.036),
        (40, -0.044), (50, -0.049), (60, -0.059), (75, -0.062), (100, -0.054),
        (125, -0.054)
    ],
    "W9": [
        (9, -0.095), (15, -0.102), (20, -0.123), (25, -0.148), (30, -0.168),
        (40, -0.176), (50, -0.171), (60, -0.163), (75, -0.183), (100, -0.173),
        (125, -0.181)
    ]
}

# %%
plt.figure(figsize=(14, 8))
for i, (segment_name, points) in enumerate(data_bbldisc.items()):
    x, y = zip(*points)
    x_positions = [xi + i * 0.5 for xi in x]
    plt.bar(x_positions, y, width=0.5, label=segment_name)

plt.title('BBERT-L-D (I) $l$ vs $d$')
plt.xlabel('$l$')
plt.ylabel('$d$')
plt.legend(title="")

plt.savefig('BBERT-L-D (I).pdf')

# %% [markdown]
# # XLM RoBERTa Large

# %%
data_xlmrobertal = {
    "W1": [
        (9, -0.028), (15, 0.074), (20, 0.083), (25, 0.138), (30, 0.160),
        (40, 0.215), (50, 0.232), (60, 0.240), (75, 0.228), (100, 0.194),
        (125, 0.232)
    ],
    "W2": [
        (9, 0.526), (15, 0.726), (20, 0.743), (25, 0.764), (30, 0.764),
        (40, 0.794), (50, 0.777), (60, 0.794), (75, 0.806), (100, 0.811),
        (125, 0.828)
    ],
    "W3": [
        (9, 0.130), (15, 0.045), (20, 0.019), (25, 0.045), (30, 0.028),
        (40, 0.028), (50, 0.032), (60, 0.045), (75, 0.045), (100, 0.045),
        (125, 0.049)
    ],
    "W4": [
        (9, -0.117), (15, -0.185), (20, -0.177), (25, -0.211), (30, -0.194),
        (40, -0.194), (50, -0.198), (60, -0.206), (75, -0.211), (100, -0.189),
        (125, -0.215)
    ],
    "W5": [
        (9, 0.313), (15, 0.300), (20, 0.274), (25, 0.232), (30, 0.215),
        (40, 0.181), (50, 0.185), (60, 0.198), (75, 0.185), (100, 0.223),
        (125, 0.202)
    ],
    "W6": [
        (9, -0.291), (15, -0.228), (20, -0.202), (25, -0.172), (30, -0.160),
        (40, -0.143), (50, -0.134), (60, -0.143), (75, -0.096), (100, -0.083),
        (125, -0.155)
    ],
    "W7": [
        (9, -0.721), (15, -0.726), (20, -0.772), (25, -0.840), (30, -0.836),
        (40, -0.840), (50, -0.857), (60, -0.870), (75, -0.840), (100, -0.849),
        (125, -0.845)
    ],
    "W8": [
        (9, -0.330), (15, -0.351), (20, -0.351), (25, -0.364), (30, -0.372),
        (40, -0.385), (50, -0.377), (60, -0.368), (75, -0.347), (100, -0.381),
        (125, -0.364)
    ],
    "W9": [
        (9, -0.198), (15, -0.130), (20, -0.126), (25, -0.113), (30, -0.126),
        (40, -0.126), (50, -0.117), (60, -0.121), (75, -0.126), (100, -0.143),
        (125, -0.134)
    ]
}

# %%
plt.figure(figsize=(14, 8))
for i, (segment_name, points) in enumerate(data_xlmrobertal.items()):
    x, y = zip(*points)
    x_positions = [xi + i * 0.5 for xi in x]
    plt.bar(x_positions, y, width=0.5, label=segment_name)

plt.title('XLM-RoBERTa-L (I) $l$ vs $d$')
plt.xlabel('$l$')
plt.ylabel('$d$')
plt.legend(title="", loc='upper right')

plt.savefig('XLM-RoBERTa-L (I).pdf')
